# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.20.1'

# %%
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv')

# %%
data
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df = pd.DataFrame(data)

# %%
df[['Make','Model']]
# Out:
#           Make       Model
# 0          BMW  1 Series M
# 1          BMW    1 Series
# 2          BMW    1 Series
# 3          BMW    1 Series
# 4          BMW    1 Series
# ...        ...         ...
# 11909    Acura         ZDX
# 11910    Acura         ZDX
# 11911    Acura         ZDX
# 11912    Acura         ZDX
# 11913  Lincoln      Zephyr
#
# [11914 rows x 2 columns]

# %%
df.len
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-55f00639177d> in <module>
# ----> 1 df.len
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'len'

# %%
df.iloc[0]
# Out:
# Make                                                   BMW
# Model                                           1 Series M
# Year                                                  2011
# Engine Fuel Type               premium unleaded (required)
# Engine HP                                            335.0
# Engine Cylinders                                       6.0
# Transmission Type                                   MANUAL
# Driven_Wheels                             rear wheel drive
# Number of Doors                                        2.0
# Market Category      Factory Tuner,Luxury,High-Performance
# Vehicle Size                                       Compact
# Vehicle Style                                        Coupe
# highway MPG                                             26
# city mpg                                                19
# Popularity                                            3916
# MSRP                                                 46135
# ...

# %%
len(df)
# Out:
# 11914

# %%
len(df.index)
# Out:
# 11914

# %%
freq_make = df['Make'].value_counts()

# %%
freq_make
# Out:
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %%
audi = df[df['Make']=='Audi']

# %%
audi
# Out:
#        Make Model  Year             Engine Fuel Type  Engine HP  \
# 17     Audi   100  1992             regular unleaded      172.0
# 18     Audi   100  1992             regular unleaded      172.0
# 19     Audi   100  1992             regular unleaded      172.0
# 20     Audi   100  1992             regular unleaded      172.0
# 21     Audi   100  1992             regular unleaded      172.0
# ...     ...   ...   ...                          ...        ...
# 10901  Audi   TTS  2016  premium unleaded (required)      292.0
# 10902  Audi   TTS  2017  premium unleaded (required)      292.0
# 11178  Audi    V8  1992             regular unleaded      276.0
# 11179  Audi    V8  1993             regular unleaded      276.0
# 11180  Audi    V8  1994             regular unleaded      276.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 17                  6.0            MANUAL  front wheel drive              4.0
# ...

# %%
make_model=df.groupby(['Make','Model'])['Model'].count()

# %%
audi_df = df[df[['Make','Model']]=="Audi"]

# %%
audi_df_unique=audi_df.drop_duplicates()

# %%
audi_unique=audi.drop_duplicates(subset="Model")

# %%
len(audi_unique)
# Out:
#        Make            Model  Year                Engine Fuel Type  Engine HP  \
# 17     Audi              100  1992                regular unleaded      172.0
# 58     Audi              200  1990                regular unleaded      162.0
# 766    Audi               80  1990                regular unleaded      108.0
# 911    Audi               90  1993                regular unleaded      172.0
# 1014   Audi               A3  2015                          diesel      150.0
# 1061   Audi       A4 allroad  2017  premium unleaded (recommended)      252.0
# 1064   Audi               A4  2015     premium unleaded (required)      220.0
# 1089   Audi               A5  2016     premium unleaded (required)      220.0
# 1098   Audi               A6  2015                          diesel      240.0
# 1121   Audi               A7  2015     premium unleaded (required)      310.0
# 1131   Audi               A8  2016                          diesel      240.0
# ...

# %%
df.isnull().any().sum()
# Out:
# 5

# %%
df['Engine Cylinders'].median()
# Out:
# 6.0

# %%
df['Engine Cylinders'].value_counts()
# Out:
# 4.0     4752
# 6.0     4489
# 8.0     2031
# 12.0     230
# 5.0      225
# 10.0      68
# 0.0       56
# 3.0       30
# 16.0       3
# Name: Engine Cylinders, dtype: int64

# %%
df['Engine Cylinders'].fillna(4.0)
# Out:
# 0        6.0
# 1        6.0
# 2        6.0
# 3        6.0
# 4        6.0
#         ...
# 11909    6.0
# 11910    6.0
# 11911    6.0
# 11912    6.0
# 11913    6.0
# Name: Engine Cylinders, Length: 11914, dtype: float64

# %%
df['Engine Cylinders'].median()
# Out:
# /Users/sevil/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1111: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# nan

# %%
df['Engine Cylinders'].mode()
# Out:
# 0    4.0
# dtype: float64

# %%
df['Engine Cylinders'].isnull().any().sum()
# Out:
# 0

# %%
df[df['Engine Cylinders'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
df['Engine Cylinders'] = df['Engine Cylinders'].fillna(4.0)

# %%
df[df['Engine Cylinders'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP]
# Index: []

# %%
df['Engine Cylinders'].median()
# Out:
# 6.0

# %%
#Question 7

# %%
#Selecting Lotus cars
lotus=df[df['Make']=='Lotus']

# %%
lotus
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %%
selected_df = lotus[['Engine HP','Engine Cylinders']]

# %%
selected_df
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3914      189.0               4.0
# 3915      189.0               4.0
# 3916      218.0               4.0
# 3917      189.0               4.0
# 3918      217.0               4.0
# 3919      217.0               4.0
# 4216      350.0               8.0
# 4217      350.0               8.0
# 4218      350.0               8.0
# 4257      400.0               6.0
# 4258      400.0               6.0
# 4259      276.0               6.0
# 4260      276.0               6.0
# 4261      276.0               6.0
# 4262      345.0               6.0
# 4263      345.0               6.0
# 4264      276.0               6.0
# 4265      345.0               6.0
# 4266      276.0               6.0
# 4267      345.0               6.0
# 4268      276.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0
# 4294      240.0               4.0
# ...

# %%
selected_df = selected_df.drop_duplicates()

# %%
selected_df
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3918      217.0               4.0
# 4216      350.0               8.0
# 4257      400.0               6.0
# 4259      276.0               6.0
# 4262      345.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0

# %%
X = np.array(selected_df)

# %%
X.shape
# Out:
# (9, 2)

# %%
XT=X.T

# %%
XTX = (XT).dot(X)

# %%
XTX
# Out:
# array([[7.31684e+05, 1.34100e+04],
#        [1.34100e+04, 2.52000e+02]])

# %%
inversed_xtx = np.linalg.inv(XTX)

# %%
inversed_xtx.shape
# Out:
# (2, 2)

# %%
y = [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800]

# %%
y = np.array(y)

# %%
XTX = XT.dot(X)

# %%
new=inversed_xtx.dot(XT)

# %%
IXTXbyXT = inversed_xtx.dot(XT)
w = IXTXbyXT.dot(y)

# %%
w
# Out:
# array([  4.59494481, -63.56432501])

# %%
w[0]
# Out:
# 4.594944810094579
